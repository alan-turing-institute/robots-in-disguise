# %% [markdown]
# # Infrence with fine-tuned GPT2 with Hugging Face Transformers

# %%
# %pip install datasets transformers==4.28.0
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting datasets
#   Downloading datasets-2.12.0-py3-none-any.whl (474 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 474.6/474.6 kB 22.4 MB/s eta 0:00:00
# Collecting transformers==4.28.0
#   Downloading transformers-4.28.0-py3-none-any.whl (7.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.0/7.0 MB 83.6 MB/s eta 0:00:00
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from transformers==4.28.0) (3.12.0)
# Collecting huggingface-hub<1.0,>=0.11.0 (from transformers==4.28.0)
#   Downloading huggingface_hub-0.14.1-py3-none-any.whl (224 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 224.5/224.5 kB 27.1 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from transformers==4.28.0) (1.22.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from transformers==4.28.0) (23.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers==4.28.0) (6.0)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers==4.28.0) (2022.10.31)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from transformers==4.28.0) (2.27.1)
# Collecting tokenizers!=0.11.3,<0.14,>=0.11.1 (from transformers==4.28.0)
#   Downloading tokenizers-0.13.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (7.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 116.2 MB/s eta 0:00:00
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.10/dist-packages (from transformers==4.28.0) (4.65.0)
# Requirement already satisfied: pyarrow>=8.0.0 in /usr/local/lib/python3.10/dist-packages (from datasets) (9.0.0)
# Collecting dill<0.3.7,>=0.3.0 (from datasets)
#   Downloading dill-0.3.6-py3-none-any.whl (110 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 110.5/110.5 kB 13.2 MB/s eta 0:00:00
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from datasets) (1.5.3)
# Collecting xxhash (from datasets)
#   Downloading xxhash-3.2.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (212 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 212.5/212.5 kB 25.4 MB/s eta 0:00:00
# Collecting multiprocess (from datasets)
#   Downloading multiprocess-0.70.14-py310-none-any.whl (134 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.3/134.3 kB 14.6 MB/s eta 0:00:00
# Requirement already satisfied: fsspec[http]>=2021.11.1 in /usr/local/lib/python3.10/dist-packages (from datasets) (2023.4.0)
# Collecting aiohttp (from datasets)
#   Downloading aiohttp-3.8.4-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 28.0 MB/s eta 0:00:00
# Collecting responses<0.19 (from datasets)
#   Downloading responses-0.18.0-py3-none-any.whl (38 kB)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (23.1.0)
# Requirement already satisfied: charset-normalizer<4.0,>=2.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (2.0.12)
# Collecting multidict<7.0,>=4.5 (from aiohttp->datasets)
#   Downloading multidict-6.0.4-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (114 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 114.5/114.5 kB 12.4 MB/s eta 0:00:00
# Collecting async-timeout<5.0,>=4.0.0a3 (from aiohttp->datasets)
#   Downloading async_timeout-4.0.2-py3-none-any.whl (5.8 kB)
# Collecting yarl<2.0,>=1.0 (from aiohttp->datasets)
#   Downloading yarl-1.9.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (268 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 268.8/268.8 kB 29.2 MB/s eta 0:00:00
# Collecting frozenlist>=1.1.1 (from aiohttp->datasets)
#   Downloading frozenlist-1.3.3-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (149 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 149.6/149.6 kB 20.8 MB/s eta 0:00:00
# Collecting aiosignal>=1.1.2 (from aiohttp->datasets)
#   Downloading aiosignal-1.3.1-py3-none-any.whl (7.6 kB)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.11.0->transformers==4.28.0) (4.5.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->transformers==4.28.0) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->transformers==4.28.0) (2022.12.7)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->transformers==4.28.0) (3.4)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets) (2022.7.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.1->pandas->datasets) (1.16.0)
# Installing collected packages: tokenizers, xxhash, multidict, frozenlist, dill, async-timeout, yarl, responses, multiprocess, huggingface-hub, aiosignal, transformers, aiohttp, datasets
# Successfully installed aiohttp-3.8.4 aiosignal-1.3.1 async-timeout-4.0.2 datasets-2.12.0 dill-0.3.6 frozenlist-1.3.3 huggingface-hub-0.14.1 multidict-6.0.4 multiprocess-0.70.14 responses-0.18.0 tokenizers-0.13.3 transformers-4.28.0 xxhash-3.2.0 yarl-1.9.2

# %%
from google.colab import drive
import os
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ## Using the model

# %%
# Load the trained model from the disk
from transformers import AutoModelForCausalLM

saved_model = AutoModelForCausalLM.from_pretrained('./drive/MyDrive/REGindald-trained/reginald-distilgpt2-10/', local_files_only=True)

# %%
from transformers import AutoTokenizer

# We also need to get the tokenizer again!
checkpoint = 'distilgpt2'
tokenizer = AutoTokenizer.from_pretrained(checkpoint)
# Out:
# Downloading (…)lve/main/config.json:   0%|          | 0.00/762 [00:00<?, ?B/s]
# Downloading (…)olve/main/vocab.json:   0%|          | 0.00/1.04M [00:00<?, ?B/s]
# Downloading (…)olve/main/merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# Downloading (…)/main/tokenizer.json:   0%|          | 0.00/1.36M [00:00<?, ?B/s]

# %%
import torch
from transformers import pipeline

# Using text-generation pipeline
# Hugging Face has pipelines for all standardized tasks

device = 'cuda:0'
pipe = pipeline(
    "text-generation", 
    model=saved_model, 
    device=device, 
    tokenizer=tokenizer
)

# %%
def generate_and_print(inputs, n, output_length):
  outputs = pipe(inputs, num_return_sequences=n, max_new_tokens=output_length)
  for x in outputs[0]:
    print(x['generated_text'])
  
generate_and_print(["In the Research Engineering Group in the Alan Turing Institute, Evelina"], 10,50)
# Out:
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# In the Research Engineering Group in the Alan Turing Institute, Evelina and Ellinghausen discussed the nature of the cognitive training program of modern research on computer models, and how its goal was to address these issues through the early stage of the research. They included Evelina‣s new presentation to the Society
# In the Research Engineering Group in the Alan Turing Institute, Evelina Mejkovic, a physicist at Tel Aviv University, has been working on a paper linking the concept of quantum computers to the development of quantum computers, a paper published today by Science.
#
#
#
#
#
# In the paper at the Institute
# In the Research Engineering Group in the Alan Turing Institute, Evelina Smith, Evelina Smith and Evelina Smith (2013). The National Institutes of Health: Biological, Biomedical and Statistical Research, 10th eds.; John F. Jones (in response to the Nobel Prize in Physics, 2009).
#
# In the Research Engineering Group in the Alan Turing Institute, Evelina's contribution to the research team had become apparent. The results had been published earlier this season. The team also published a paper on whether these differences could be explained when non-fictional factors like the number of tests performed during human trials and whether the
# In the Research Engineering Group in the Alan Turing Institute, Evelina van Steen and colleagues work on the development of high-powered quantum quantum computers and the development of superconductive quantum computers.
#
#
#
#
# The researchers created the quantum computer (or Quimm.) at MIT and its partner-in
# In the Research Engineering Group in the Alan Turing Institute, Evelina De Bletis and her colleagues have found the most promising approach to making artificial intelligence (AI) work on machines is a form of artificial intelligence (AI). This approach is not new in the field, but the paper has been compared with a similar
# In the Research Engineering Group in the Alan Turing Institute, Evelina and Nuremberg (GitHub) are collaborating in a new class of papers by Jurgen van der Hoevens in the Proceedings of the International Conference on Artificial Intelligence.
#
#
#
# Evelina and Nuremberg are
# In the Research Engineering Group in the Alan Turing Institute, Evelina Kuznetsov is a fellow at Harvard and has written the groundbreaking The New Deal.
# In the Research Engineering Group in the Alan Turing Institute, Evelina said: "This does not mean that our understanding of language has changed. When we look at how language is developed we only see one part. There is some agreement in terms of where the language will evolve. By extension, we would have to adapt
# In the Research Engineering Group in the Alan Turing Institute, Evelina Kollins wrote. “The basic idea is that we have a number that are just a few billion to the degree that they are all a couple billion to the degree that we are in general.” The “right of the people
